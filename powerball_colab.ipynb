# %% [markdown]
# # Powerball Colab Pipeline
#
# This notebook downloads and runs the pipeline script in this repository. It is configured to use hosted Hugging Face inference for optional LLM generator/critic/arbiter steps if you set an environment variable `HUGGINGFACE_API_TOKEN`.
#
# Open-in-Colab: https://colab.research.google.com/github/6msjfv782z-ctrl/powerball-colab-pipeline/blob/main/powerball_colab.ipynb

# %%
# Install requirements
# !pip install -q -r requirements.txt

# Download the pipeline script from the repo and run it
# !curl -s -O https://raw.githubusercontent.com/6msjfv782z-ctrl/powerball-colab-pipeline/main/colab_pipeline.py
python_cmd = 'python colab_pipeline.py'
print('Running pipeline (this may take a few minutes)...')
# !python colab_pipeline.py
